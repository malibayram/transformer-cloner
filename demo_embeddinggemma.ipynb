# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("google/embeddinggemma-300m")

sentences = [
    "That is a happy person",
    "That is a happy dog",
    "That is a very happy person",
    "Today is a sunny day"
]
embeddings = model.encode(sentences)

similarities = model.similarity(embeddings, embeddings)
similarities
# Out:
# You are trying to use a model that was created with Sentence Transformers version 5.1.0, but you're currently using version 4.1.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]
# tensor([[1.0000, 0.8078, 0.9839, 0.5595],
#         [0.8078, 1.0000, 0.7960, 0.5486],
#         [0.9839, 0.7960, 1.0000, 0.5417],
#         [0.5595, 0.5486, 0.5417, 1.0000]])

# %%
from transformers import GemmaTokenizerFast, Gemma3ForCausalLM

s_tokenizer = GemmaTokenizerFast.from_pretrained("embeddinggemma")
s_model = Gemma3ForCausalLM.from_pretrained("embeddinggemma")
s_model
# Out:
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]
# Gemma3ForCausalLM(
#   (model): Gemma3TextModel(
#     (embed_tokens): Gemma3TextScaledWordEmbedding(262144, 768, padding_idx=0)
#     (layers): ModuleList(
#       (0-23): 24 x Gemma3DecoderLayer(
#         (self_attn): Gemma3Attention(
#           (q_proj): Linear(in_features=768, out_features=768, bias=False)
#           (k_proj): Linear(in_features=768, out_features=256, bias=False)
#           (v_proj): Linear(in_features=768, out_features=256, bias=False)
#           (o_proj): Linear(in_features=768, out_features=768, bias=False)
#           (q_norm): Gemma3RMSNorm((256,), eps=1e-06)
#           (k_norm): Gemma3RMSNorm((256,), eps=1e-06)
#         )
#         (mlp): Gemma3MLP(
#           (gate_proj): Linear(in_features=768, out_features=1152, bias=False)
#           (up_proj): Linear(in_features=768, out_features=1152, bias=False)
#           (down_proj): Linear(in_features=1152, out_features=768, bias=False)
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

a_tokenizer = AutoTokenizer.from_pretrained("alibayram/gemma3-141m-stage2-books")
a_model = AutoModelForCausalLM.from_pretrained("alibayram/gemma3-141m-stage2-books")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/36.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/555 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/285M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/236 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]

# %%
a_tokenizer.save_pretrained("./embeddinggemma")
# Out:
# ('./embeddinggemma/tokenizer_config.json',
#  './embeddinggemma/chat_template.jinja',
#  './embeddinggemma/tokenizer.json')

# %%
a_model.save_pretrained("./embeddinggemma")

# %%
from sentence_transformers import SentenceTransformer

a_sentence_transformer = SentenceTransformer("embeddinggemma")
a_sentence_transformer
# Out:
# Loading weights:   0%|          | 0/236 [00:00<?, ?it/s]
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 2048, 'do_lower_case': False}) with Transformer model: Gemma3TextModel
#   (1): Pooling({'word_embedding_dimension': 640, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Dense({'in_features': 640, 'out_features': 3072, 'bias': False, 'activation_function': 'torch.nn.modules.linear.Identity'})
#   (3): Dense({'in_features': 3072, 'out_features': 640, 'bias': False, 'activation_function': 'torch.nn.modules.linear.Identity'})
#   (4): Normalize()
# )

# %%
a_embeddings = a_sentence_transformer.encode(sentences)
print(a_embeddings.shape)
a_similarities = a_sentence_transformer.similarity(a_embeddings, a_embeddings)
a_similarities
# Out:
# (4, 640)
# tensor([[   nan,    nan,    nan,    nan],
#         [   nan,    nan,    nan,    nan],
#         [   nan,    nan,    nan,    nan],
#         [   nan,    nan,    nan, 1.0000]])
